# %%
#import libraries
from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib

# %%
#connect to website and pull the data
url='https://www.amazon.in/Seek-Buy-Love-Spreadsheet-Accountant/dp/B0DNRPGBQT/ref=sr_1_7?crid=2JNL2L20KX8MJ&dib=eyJ2IjoiMSJ9.A1lhbGb3DX8onxsZQC4DfenARcP_4xnHXZ-sMKmIZbd35SAmo1jDWquE6DENyWjJ4g9AY7g4IHgIB0KVpgBCJ8-azJnk145rpfYLQPcK-c_GxB2vvcmri4xGcVCVtOtM0j8L7beeE8PzDWRpnV-UhZ3npvsXGOAx09f-sBa6CxaocKgmRf9D8SZj4ro1-85jylkSzKifaj2R_ppRVQTuMANnse1Xg59yyLScHYgc9SoXUztaVts612mirn_SemPdUdybV-G3ArYKxDy-ahUZaAc3ZU3pZXJw_m8SWfBmQtY.FDxkk1I_zrrThA3V3HQXBlSqK41JWRfIrvPe2HlUnMU&dib_tag=se&keywords=data+analyst+tshirt&qid=1780543389&sprefix=%2Caps%2C1054&sr=8-7'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"
}
page=requests.get(url,headers=headers)
soup1=BeautifulSoup(page.content,"html.parser")
soup2=BeautifulSoup(soup1.prettify(),"html.parser")
title=soup2.find(id='productTitle').get_text().strip()
title=title.replace('.','').strip()
price=soup2.find(class_='a-price-whole').get_text().strip()
price=price.replace('\n','').replace('.','').strip()
symbol=soup2.find(class_='a-price-symbol').get_text().strip()
print(symbol.strip()+price.strip())
print(title)
print(repr(title))
print(repr(price))
print(repr(symbol))
# Out:
# ₹490
# Relax Spreadsheet Funny T-Shirt, Accountant Financial Analyst Tee, Casual Office Humor Graphic Shirt, Unisex Cotton Top
# 'Relax Spreadsheet Funny T-Shirt, Accountant Financial Analyst Tee, Casual Office Humor Graphic Shirt, Unisex Cotton Top'
# '490'
# '₹'

# %%
# Create a Timestamp for your output to track when data was collected
import datetime
today=datetime.date.today()
print(today)
# Out:
# 2026-06-05

# %%
# Create CSV and write headers and data into the file
import csv
header=['Title','Price','Date']
title=title.replace(',','')
data=[title,symbol.strip()+price.strip(),today]
print(type(data))
with open('AmazonWebScrapper.csv','w',newline='',encoding='UTF-8-sig') as f:
      writer=csv.writer(f)
      writer.writerow(header)
      writer.writerow(data)
print(data)
print("csv saved")
# Out:
# <class 'list'>
# ['Relax Spreadsheet Funny T-Shirt Accountant Financial Analyst Tee Casual Office Humor Graphic Shirt Unisex Cotton Top', '₹490', datetime.date(2026, 6, 5)]
# csv saved

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\PC\AmazonWebScrapper.csv')
print(df)
# Out:
#                                                Title Price        Date
# 0  Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05

# %%
#now appending the data
with open('AmazonWebScrapper.csv','a+',newline='',encoding='UTF=8-sig')as f:
    writer=csv.writer(f)
    writer.writerow(data)
    print("row saved sucessfully")
# Out:
# row saved sucessfully

# %%
def check_price():
        print("function started")
        url='https://www.amazon.in/Seek-Buy-Love-Spreadsheet-Accountant/dp/B0DNRPGBQT/ref=sr_1_7?crid=2JNL2L20KX8MJ&dib=eyJ2IjoiMSJ9.A1lhbGb3DX8onxsZQC4DfenARcP_4xnHXZ-sMKmIZbd35SAmo1jDWquE6DENyWjJ4g9AY7g4IHgIB0KVpgBCJ8-azJnk145rpfYLQPcK-c_GxB2vvcmri4xGcVCVtOtM0j8L7beeE8PzDWRpnV-UhZ3npvsXGOAx09f-sBa6CxaocKgmRf9D8SZj4ro1-85jylkSzKifaj2R_ppRVQTuMANnse1Xg59yyLScHYgc9SoXUztaVts612mirn_SemPdUdybV-G3ArYKxDy-ahUZaAc3ZU3pZXJw_m8SWfBmQtY.FDxkk1I_zrrThA3V3HQXBlSqK41JWRfIrvPe2HlUnMU&dib_tag=se&keywords=data+analyst+tshirt&qid=1780543389&sprefix=%2Caps%2C1054&sr=8-7'
        headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"
              }
        page=requests.get(url,headers=headers)
        soup1=BeautifulSoup(page.content,"html.parser")
        soup2=BeautifulSoup(soup1.prettify(),"html.parser")
        title=soup2.find(id='productTitle').get_text().strip()
        title=title.replace('.','').strip()
        price=soup2.find(class_='a-price-whole').get_text().strip()
        price=price.replace('\n','').replace('.','').strip()
        symbol=soup2.find(class_='a-price-symbol').get_text().strip()
        import datetime
        today=datetime.date.today()
        import csv
        header=['Title','Price','Date']
        title=title.replace(',','')
        data=[title,symbol.strip()+price.strip(),today]
        with open('AmazonWebScrapper.csv','a+',newline='',encoding='UTF=8-sig')as f:
            writer=csv.writer(f)
            writer.writerow(data)
            print("row saved sucessfully")
check_price()
# Out:
# function started
# row saved sucessfully

# %%
while(True):
    check_price()
    time.sleep(5)
# Out:
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# function started
# row saved sucessfully
# ...

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\PC\AmazonWebScrapper.csv')
print(df)
# Out:
#                                                 Title Price        Date
# 0   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 1   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 2   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 3   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 4   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 5   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 6   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 7   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 8   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 9   Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 10  Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# 11  Relax Spreadsheet Funny T-Shirt Accountant Fin...  ₹490  2026-06-05
# ...
